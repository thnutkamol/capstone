# %%
import numpy as np
import pandas as pd
import tweepy
import matplotlib.pyplot as plt
import pymongo
import ipywidgets as wgt
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
import re
from datetime import datetime

# %%
api_key = 'pCRLPdf2lkjpRX9Uczpt2gVBb'
api_secret = 'G1Wv7sTLMYF3cr5LbL8S9uj2g2LFrdWp8X8t7Ft3sIpW0kbqgD'
access_token = '100875722-7m5vhOzpw2LYrB7P8ISnTqtGYMMvVTqwx3X4EyJY'
access_token_secret = 'uPEymGiszhiJEVWD4Alo1pzMUJx1ymo3Fd4HWyRPRBN3r'

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
col = pymongo.MongoClient()["twitter"]["trump1"]
col.count()
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   # This is added back by InteractiveShellApp.init_path()
# 5000

# %%
class MyStreamListener(tweepy.StreamListener):
    
    counter = 0
    
    def __init__(self, max_tweets=5000, *args, **kwargs):
        self.max_tweets = max_tweets
        self.counter = 0
        super().__init__(*args, **kwargs)
    
    def on_connect(self):
        self.counter = 0
        self.start_time = datetime.now()
    
    def on_status(self, status):
        # Increment counter
        self.counter += 1
        
        # Store tweet to MongoDB
        col.insert_one(status._json)
        
        
        if self.counter % 1 == 0:
            value = int(100.00 * self.counter / self.max_tweets)
            mining_time = datetime.now() - self.start_time
            progress_bar.value = value
            html_value = """<span class="label label-primary">Tweets/Sec: %.1f</span>""" % (self.counter / max([1,mining_time.seconds]))
            html_value += """ <span class="label label-success">Progress: %.1f%%</span>""" % (self.counter / self.max_tweets * 100.0)
            html_value += """ <span class="label label-info">ETA: %.1f Sec</span>""" % ((self.max_tweets - self.counter) / (self.counter / max([1,mining_time.seconds])))
            wgt_status.value = html_value
            #print("%s/%s" % (self.counter, self.max_tweets))
            if self.counter >= self.max_tweets:
                myStream.disconnect()
                print("Finished")
                print("Total Mining Time: %s" % (mining_time))
                print("Tweets/Sec: %.1f" % (self.max_tweets / mining_time.seconds))
                progress_bar.value = 0
                
    
myStreamListener = MyStreamListener(max_tweets=5000)
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
keywords = ["Donald Trump",
            "Trump"
           ]

# Visualize a progress bar to track progress
progress_bar = wgt.IntProgress(value=0)
display(progress_bar)
wgt_status = wgt.HTML(value="""<span class="label label-primary">Tweets/Sec: 0.0</span>""")
display(wgt_status)

# Start a filter with an error counter of 20
for error_counter in range(20):
    try:
        myStream.filter(track=keywords)
        print("Tweets collected: %s" % myStream.listener.counter)
        print("Total tweets in collection: %s" % col.count())
        break
    except:
        print("ERROR# %s" % (error_counter + 1))
# Out:
# IntProgress(value=0)
# HTML(value='<span class="label label-primary">Tweets/Sec: 0.0</span>')
# Finished
# Total Mining Time: 0:02:41.949935
# Tweets/Sec: 31.1
# Tweets collected: 5000
# Total tweets in collection: 5000
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5f9e5fe5023d75a6309fa090'),
#  'created_at': 'Sun Nov 01 07:12:32 +0000 2020',
#  'id': 1322798662649552896,
#  'id_str': '1322798662649552896',
#  'text': "RT @vicksiern: @RuthieRedSox @MLH915 @realDonaldTrump Let's Vote for President Trump and make this the most votes any President has ever re…",
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1062054013020110850,
#   'id_str': '1062054013020110850',
#   'name': 'Eileen Rodriguez',
#   'screen_name': 'EileenR03470030',
#   'location': None,
#   'url': None,
#   'description': "I am a veteran of the USN for 6yrs. Always new something wasn't right and am glad I took the RED PILL to see I was correct. Just hoping more will take the pill.",
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 965,
#   'friends_count': 771,
#   'listed_count': 0,
#   'favourites_count': 71389,
#   'statuses_count': 69373,
#   'created_at': 'Mon Nov 12 18:46:23 +0000 2018',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1316298522044628992/BznxO_Ep_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316298522044628992/BznxO_Ep_normal.jpg',
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sun Nov 01 06:58:40 +0000 2020',
#   'id': 1322795173101801472,
#   'id_str': '1322795173101801472',
#   'text': "@RuthieRedSox @MLH915 @realDonaldTrump Let's Vote for President Trump and make this the most votes any President has ever received!",
#   'display_text_range': [39, 131],
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1322640220177784832,
#   'in_reply_to_status_id_str': '1322640220177784832',
#   'in_reply_to_user_id': 1931084401,
#   'in_reply_to_user_id_str': '1931084401',
#   'in_reply_to_screen_name': 'RuthieRedSox',
#   'user': {'id': 899149856,
#    'id_str': '899149856',
#    'name': 'vicki cecilX',
#    'screen_name': 'vicksiern',
#    'location': None,
#    'url': None,
#    'description': '#MAGA. I will spend as much time trying to save America from Socialism as I can so my children and grandchildren will continue to have the freedom.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 28765,
#    'friends_count': 30202,
#    'listed_count': 43,
#    'favourites_count': 133384,
#    'statuses_count': 154414,
#    'created_at': 'Tue Oct 23 04:10:49 +0000 2012',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291424084400549889/7XYljulh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291424084400549889/7XYljulh_normal.jpg',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 5,
#   'favorite_count': 3,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'RuthieRedSox',
#      'name': 'RuthieRedSox',
#      'id': 1931084401,
#      'id_str': '1931084401',
#      'indices': [0, 13]},
#     {'screen_name': 'MLH915',
#      'name': 'Mari4Trump',
#      'id': 3446851336,
#      'id_str': '3446851336',
#      'indices': [14, 21]},
#     {'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [22, 38]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'vicksiern',
#     'name': 'vicki cecilX',
#     'id': 899149856,
#     'id_str': '899149856',
#     'indices': [3, 13]},
#    {'screen_name': 'RuthieRedSox',
#     'name': 'RuthieRedSox',
#     'id': 1931084401,
#     'id_str': '1931084401',
#     'indices': [15, 28]},
#    {'screen_name': 'MLH915',
#     'name': 'Mari4Trump',
#     'id': 3446851336,
#     'id_str': '3446851336',
#     'indices': [29, 36]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [37, 53]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1604214752243'}

# %%
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
            "user": "@%s" % item["user"]["screen_name"],
            "source": item["source"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
#                        created_at  \
# 0  Sun Nov 01 07:12:32 +0000 2020
# 1  Sun Nov 01 07:12:32 +0000 2020
# 2  Sun Nov 01 07:12:32 +0000 2020
# 3  Sun Nov 01 07:12:32 +0000 2020
# 4  Sun Nov 01 07:12:32 +0000 2020
#
#                                                 text              user  \
# 0  RT @vicksiern: @RuthieRedSox @MLH915 @realDona...  @EileenR03470030
# 1  RT @MEL2AUSA: @JoeBiden TRUMP 2020 🇺🇸 \nhttps:...   @LadyChesapeake
# 2  @GOP @realDonaldTrump I voted for President Tr...         @GRRE1955
# 3  RT @PetaniKg: Kata Biden 9 points atas Trump. ...         @RuhLong_
# 4  RT @thebradfordfile: Democrats are losing thei...           @Ava70h
#
#                                               source lang
# 0  <a href="https://mobile.twitter.com" rel="nofo...   en
# 1  <a href="https://mobile.twitter.com" rel="nofo...   en
# 2  <a href="http://twitter.com/download/android" ...   en
# 3  <a href="http://twitter.com/download/iphone" r...   in
# 4  <a href="https://mobile.twitter.com" rel="nofo...   en

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(dataset.text)

word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt   3599
# 1             trump   3298
# 2               the   2593
# 3             https   1667
# 4                co   1645
# 5                to   1605
# 6                is   1393
# 7                in   1282
# 8               and   1216
# 9                of   1213
# 10              for    994
# 11            biden    776
# 12             this    654
# 13        president    645
# 14               it    620
# 15              you    597
# 16             that    588
# 17              are    534
# 18               on    453
# 19               we    433
# 20               he    429
# 21              can    385
# 22              his    383
# 23               if    365
# 24             they    364
# 25       supporters    356
# 26  realdonaldtrump    353
# 27               up    345
# 28           donald    339
# 29             more    330
# 30              not    307
# 31             have    305
# 32              has    302
# 33               be    297
# 34             from    276
# 35               at    271
# 36               pa    271
# 37             just    267
# 38             vote    266
# 39               no    266
# 40              000    261
# 41             with    251
# 42           people    246
# 43              all    246
# 44               by    244
# 45           butler    238
# 46             your    235
# 47              but    223
# 48             will    221
# 49   realjameswoods    215

# %%
def get_source_name(x):
    value = re.findall(pattern="<[^>]+>([^<]+)</a>", string=x)
    if len(value) > 0:
        return value[0]
    else:
        return ""
dataset.source_name = dataset.source.apply(get_source_name)

source_counts = dataset.source_name.value_counts().sort_values()[-10:]

bottom = [index for index, item in enumerate(source_counts.index)]
plt.barh(bottom, width=source_counts, color="blue", linewidth=0)

y_labels = ["%s %.1f%%" % (item, 100.0*source_counts[item]/len(dataset)) for index,item in enumerate(source_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)

source_counts
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   import sys
# Cheap Bots, Done Quick!       6
# Tweetbot for iΟS              7
# Twitterrific for iOS          7
# TweetDeck                    10
# WordPress.com                10
# IFTTT                        58
# Twitter for iPad            283
# Twitter Web App            1182
# Twitter for Android        1508
# Twitter for iPhone         1870
# Name: source, dtype: int64

# %%
lang_counts = dataset.lang.value_counts().sort_values()[-10:]
bottom = [index for index, item in enumerate(lang_counts.index)]
plt.barh(bottom, width=lang_counts, color="green", linewidth=0)
y_labels = ["%s %.1f%%" % (item, 100.0*lang_counts[item]/len(dataset)) for index,item in enumerate(lang_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)
lang_counts
# Out:
# no       10
# pt       14
# tr       16
# nl       16
# it       25
# de       45
# fr       46
# es       64
# und     152
# en     4534
# Name: lang, dtype: int64

# %%
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt

# %%
dataset1 = [{"id": item["id"],
            "text": item["text"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset1 = pd.DataFrame(dataset1)
is_dataset1=dataset1.lang=="en"
dataset1=dataset1[is_dataset1]
dataset1
# Out:
#                        id                                               text  \
# 0     1322798662649552896  RT @vicksiern: @RuthieRedSox @MLH915 @realDona...
# 1     1322798662737661952  RT @MEL2AUSA: @JoeBiden TRUMP 2020 🇺🇸 \nhttps:...
# 2     1322798662905327619  @GOP @realDonaldTrump I voted for President Tr...
# 4     1322798663115149312  RT @thebradfordfile: Democrats are losing thei...
# 5     1322798663135948805  RT @Navy_Lady_45: 📢📢📢To the #UndecidedVoters \...
# ...                   ...                                                ...
# 4995  1322799341342388225  RT @RonBrownstein: Trump openly endorsing and ...
# 4996  1322799341610958848  RT @FLOTUS: On my way to the great state of Wi...
# 4997  1322799341766148096                God bless America! God bless Trump!
# 4998  1322799341879308288  RT @brianklaas: Trump is straight up endorsing...
# 4999  1322799342030331915  Trump had won. The media know it. Journalists ...
#
#      lang
# 0      en
# 1      en
# 2      en
# 4      en
# 5      en
# ...   ...
# 4995   en
# 4996   en
# 4997   en
# 4998   en
# 4999   en
#
# [4534 rows x 3 columns]

# %%
from  textblob import TextBlob
tweettext=dataset1['text']
wordlist=pd.DataFrame();

polarity=[]
subj=[]

for t in tweettext:
    tx= TextBlob(t)
    polarity.append(tx.sentiment.polarity)
    subj.append(tx.sentiment.subjectivity)

poltweet= pd.DataFrame({'polarity':polarity,'subjectivity':subj})
poltweet.polarity.plot(title='Polarity')
plt.show()

# %%
poltweet.subjectivity.plot(title='Subjectivity')
plt.show()

# %%
import statistics
statistics.mean(poltweet.polarity)
# Out:
# 0.07593357403599768

# %%
import statistics
statistics.mean(poltweet.subjectivity)
# Out:
# 0.31403623691633725

# %%
#Fuction to get clean text to get better analysis
def cleanText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

dataset1['text'] = dataset1['text'].apply(cleanText)

dataset1
# Out:
#                        id                                               text  \
# 0     1322798662649552896  :    Let's Vote for President Trump and make t...
# 1     1322798662737661952                                :  TRUMP 2020 🇺🇸 \n
# 2     1322798662905327619                       I voted for President Trump!
# 4     1322798663115149312  : Democrats are losing their minds about the l...
# 5     1322798663135948805  _Lady_45: 📢📢📢To the UndecidedVoters \n\nAre yo...
# ...                   ...                                                ...
# 4995  1322799341342388225  : Trump openly endorsing and encouraging vigil...
# 4996  1322799341610958848  : On my way to the great state of Wisconsin to...
# 4997  1322799341766148096                God bless America! God bless Trump!
# 4998  1322799341879308288  : Trump is straight up endorsing dangerous int...
# 4999  1322799342030331915  Trump had won. The media know it. Journalists ...
#
#      lang
# 0      en
# 1      en
# 2      en
# 4      en
# 5      en
# ...   ...
# 4995   en
# 4996   en
# 4997   en
# 4998   en
# 4999   en
#
# [4534 rows x 3 columns]

# %%
#Fuction to get subjectivity and polarity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

dataset1['Subjectivity'] = dataset1['text'].apply(getSubjectivity)
dataset1['Polarity'] = dataset1['text'].apply(getPolarity)

dataset1
# Out:
#                        id                                               text  \
# 0     1322798662649552896  :    Let's Vote for President Trump and make t...
# 1     1322798662737661952                                :  TRUMP 2020 🇺🇸 \n
# 2     1322798662905327619                       I voted for President Trump!
# 4     1322798663115149312  : Democrats are losing their minds about the l...
# 5     1322798663135948805  _Lady_45: 📢📢📢To the UndecidedVoters \n\nAre yo...
# ...                   ...                                                ...
# 4995  1322799341342388225  : Trump openly endorsing and encouraging vigil...
# 4996  1322799341610958848  : On my way to the great state of Wisconsin to...
# 4997  1322799341766148096                God bless America! God bless Trump!
# 4998  1322799341879308288  : Trump is straight up endorsing dangerous int...
# 4999  1322799342030331915  Trump had won. The media know it. Journalists ...
#
#      lang  Subjectivity  Polarity
# 0      en         0.500  0.500000
# 1      en         0.000  0.000000
# 2      en         0.000  0.000000
# 4      en         0.950  0.366667
# 5      en         0.700 -0.400000
# ...   ...           ...       ...
# 4995   en         0.500  0.000000
# 4996   en         0.625  0.650000
# 4997   en         0.000  0.000000
# 4998   en         0.450 -0.150000
# 4999   en         1.000  0.600000
#
# [4534 rows x 5 columns]

# %%
#Function to compute positive negative neutral analysis
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
dataset1['Analysis'] = dataset1['Polarity'].apply(getAnalysis)

dataset1
# Out:
#                        id                                               text  \
# 0     1322798662649552896  :    Let's Vote for President Trump and make t...
# 1     1322798662737661952                                :  TRUMP 2020 🇺🇸 \n
# 2     1322798662905327619                       I voted for President Trump!
# 4     1322798663115149312  : Democrats are losing their minds about the l...
# 5     1322798663135948805  _Lady_45: 📢📢📢To the UndecidedVoters \n\nAre yo...
# ...                   ...                                                ...
# 4995  1322799341342388225  : Trump openly endorsing and encouraging vigil...
# 4996  1322799341610958848  : On my way to the great state of Wisconsin to...
# 4997  1322799341766148096                God bless America! God bless Trump!
# 4998  1322799341879308288  : Trump is straight up endorsing dangerous int...
# 4999  1322799342030331915  Trump had won. The media know it. Journalists ...
#
#      lang  Subjectivity  Polarity  Analysis
# 0      en         0.500  0.500000  Positive
# 1      en         0.000  0.000000   Neutral
# 2      en         0.000  0.000000   Neutral
# 4      en         0.950  0.366667  Positive
# 5      en         0.700 -0.400000  Negative
# ...   ...           ...       ...       ...
# 4995   en         0.500  0.000000   Neutral
# 4996   en         0.625  0.650000  Positive
# 4997   en         0.000  0.000000   Neutral
# 4998   en         0.450 -0.150000  Negative
# 4999   en         1.000  0.600000  Positive
#
# [4534 rows x 6 columns]

# %%
#percentage of positive
ptweets = dataset1[dataset1.Analysis == 'Positive']
ptweets = ptweets['text']

round( (ptweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 36.4

# %%
#percentage of negative
ntweets = dataset1[dataset1.Analysis == 'Negative']
ntweets = ntweets['text']

round( (ntweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 19.5

# %%
#percentage of neutral
neutweets = dataset1[dataset1.Analysis == 'Neutral']
neutweets = neutweets['text']

round( (neutweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 44.1

# %%
dataset1['Analysis'].value_counts()

plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
dataset1['Analysis'].value_counts().plot(kind='bar')
plt.show()

# %%
import collections, numpy as np
a=twit_polarity_desc.Sentiment_Type
neut=np.count_nonzero(a == 'Neutral')
pos=np.count_nonzero(a == 'Positive')
neg=np.count_nonzero(a == 'Negative')
popularity='{0:.2f}'.format((((neut*0.5)+(pos)+(neg*0))/(neut+pos+neg))*100)
popularity
# Out:
# '58.48'

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

def wc(data,bgcolor,title):
    plt.figure(figsize = (10,10))
    wc = WordCloud(background_color = bgcolor, max_words = 100,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
top_N = 100
#convert list of list into text
#a=''.join(str(r) for v in df_usa['title'] for r in v)

a = dataset1['text'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
b = re.sub('[^A-Za-z]+', ' ', a)
nltk.download('stopwords')
#remove all the stopwords from the text
nltk.download('punkt')
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import seaborn as sns
# Remove characters which have length less than 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        

# Calculate frequency distribution
word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure()
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Common Words' )
