# %%
import numpy as np
import pandas as pd
import tweepy
import matplotlib.pyplot as plt
import pymongo
import ipywidgets as wgt
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
import re
from datetime import datetime

# %%
api_key = 'pCRLPdf2lkjpRX9Uczpt2gVBb'
api_secret = 'G1Wv7sTLMYF3cr5LbL8S9uj2g2LFrdWp8X8t7Ft3sIpW0kbqgD'
access_token = '100875722-7m5vhOzpw2LYrB7P8ISnTqtGYMMvVTqwx3X4EyJY'
access_token_secret = 'uPEymGiszhiJEVWD4Alo1pzMUJx1ymo3Fd4HWyRPRBN3r'

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
col = pymongo.MongoClient()["twitter"]["harris1"]
col.count()
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   # This is added back by InteractiveShellApp.init_path()
# 5000

# %%
class MyStreamListener(tweepy.StreamListener):
    
    counter = 0
    
    def __init__(self, max_tweets=5000, *args, **kwargs):
        self.max_tweets = max_tweets
        self.counter = 0
        super().__init__(*args, **kwargs)
    
    def on_connect(self):
        self.counter = 0
        self.start_time = datetime.now()
    
    def on_status(self, status):
        # Increment counter
        self.counter += 1
        
        # Store tweet to MongoDB
        col.insert_one(status._json)
        
        
        if self.counter % 1 == 0:
            value = int(100.00 * self.counter / self.max_tweets)
            mining_time = datetime.now() - self.start_time
            progress_bar.value = value
            html_value = """<span class="label label-primary">Tweets/Sec: %.1f</span>""" % (self.counter / max([1,mining_time.seconds]))
            html_value += """ <span class="label label-success">Progress: %.1f%%</span>""" % (self.counter / self.max_tweets * 100.0)
            html_value += """ <span class="label label-info">ETA: %.1f Sec</span>""" % ((self.max_tweets - self.counter) / (self.counter / max([1,mining_time.seconds])))
            wgt_status.value = html_value
            #print("%s/%s" % (self.counter, self.max_tweets))
            if self.counter >= self.max_tweets:
                myStream.disconnect()
                print("Finished")
                print("Total Mining Time: %s" % (mining_time))
                print("Tweets/Sec: %.1f" % (self.max_tweets / mining_time.seconds))
                progress_bar.value = 0
                
    
myStreamListener = MyStreamListener(max_tweets=5000)
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
keywords = ["Harris",
            "Kamala Harris"
           ]

# Visualize a progress bar to track progress
progress_bar = wgt.IntProgress(value=0)
display(progress_bar)
wgt_status = wgt.HTML(value="""<span class="label label-primary">Tweets/Sec: 0.0</span>""")
display(wgt_status)

# Start a filter with an error counter of 20
for error_counter in range(20):
    try:
        myStream.filter(track=keywords)
        print("Tweets collected: %s" % myStream.listener.counter)
        print("Total tweets in collection: %s" % col.count())
        break
    except:
        print("ERROR# %s" % (error_counter + 1))
# Out:
# IntProgress(value=0)
# HTML(value='<span class="label label-primary">Tweets/Sec: 0.0</span>')
# Finished
# Total Mining Time: 0:10:35.240057
# Tweets/Sec: 7.9
# Tweets collected: 5000
# Total tweets in collection: 5000
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5f9d98fd3203de9c152bf64d'),
#  'created_at': 'Sat Oct 31 17:03:51 +0000 2020',
#  'id': 1322585087012229120,
#  'id_str': '1322585087012229120',
#  'text': 'RT @EricTrump: Once again, Joe and Kamala promise to raise your taxes!',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1546973125,
#   'id_str': '1546973125',
#   'name': 'Elliot Smith',
#   'screen_name': 'elliotbsmith',
#   'location': None,
#   'url': None,
#   'description': None,
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 10,
#   'friends_count': 72,
#   'listed_count': 0,
#   'favourites_count': 52,
#   'statuses_count': 689,
#   'created_at': 'Wed Jun 26 00:22:45 +0000 2013',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000046524037/581a7f29ccba0cc5c72957bbc2db23fc_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000046524037/581a7f29ccba0cc5c72957bbc2db23fc_normal.jpeg',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sat Oct 31 12:39:13 +0000 2020',
#   'id': 1322518488821325829,
#   'id_str': '1322518488821325829',
#   'text': 'Once again, Joe and Kamala promise to raise your taxes!',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 39349894,
#    'id_str': '39349894',
#    'name': 'Eric Trump',
#    'screen_name': 'EricTrump',
#    'location': None,
#    'url': 'http://www.Trump.com',
#    'description': "Executive Vice President of The @Trump Organization. Husband to @LaraLeaTrump. Large advocate of @StJude Children's Hospital @TrumpWinery #MakeAmericaGreatAgain",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 4361373,
#    'friends_count': 1039,
#    'listed_count': 8410,
#    'favourites_count': 13806,
#    'statuses_count': 6979,
#    'created_at': 'Mon May 11 21:42:30 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': '116AB8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '616161',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1287159519743807490/A_NzWpYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287159519743807490/A_NzWpYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39349894/1516709628',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'quoted_status_id': 1322313887107239936,
#   'quoted_status_id_str': '1322313887107239936',
#   'quoted_status': {'created_at': 'Fri Oct 30 23:06:12 +0000 2020',
#    'id': 1322313887107239936,
#    'id_str': '1322313887107239936',
#    'text': '"Joe Biden and I are about to work to get rid of that tax cut," Kamala Harris tells Hispanic Americans. https://t.co/BT9sTqsDfK',
#    'display_text_range': [0, 103],
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'truncated': False,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1108472017144201216,
#     'id_str': '1108472017144201216',
#     'name': 'Trump War Room - Text TRUMP to 88022',
#     'screen_name': 'TrumpWarRoom',
#     'location': 'MAGA Country',
#     'url': 'https://www.donaldjtrump.com/',
#     'description': "Highlighting @realDonaldTrump's #PromisesKept, fighting #FakeNews. This account punches back 10x harder. Managed by the #TeamTrump 2020 campaign. #MAGA",
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 976809,
#     'friends_count': 278,
#     'listed_count': 2887,
#     'favourites_count': 99,
#     'statuses_count': 25881,
#     'created_at': 'Wed Mar 20 20:54:58 +0000 2019',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1109170568950095879/Q5nCWHLB_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109170568950095879/Q5nCWHLB_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1108472017144201216/1588976113',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'quote_count': 2434,
#    'reply_count': 2448,
#    'retweet_count': 7497,
#    'favorite_count': 12367,
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [],
#     'symbols': [],
#     'media': [{'id': 1322312618372177926,
#       'id_str': '1322312618372177926',
#       'indices': [104, 127],
#       'additional_media_info': {'title': 'Joe Biden and Kamala Harris will raise your taxes ',
#        'description': "Biden's far-left agenda will cost the average American family $6,500 per year.",
#        'embeddable': True,
#        'monetizable': False},
#       'media_url': 'http://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#       'url': 'https://t.co/BT9sTqsDfK',
#       'display_url': 'pic.twitter.com/BT9sTqsDfK',
#       'expanded_url': 'https://twitter.com/TrumpWarRoom/status/1322313887107239936/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#        'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 360, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1322312618372177926,
#       'id_str': '1322312618372177926',
#       'indices': [104, 127],
#       'additional_media_info': {'title': 'Joe Biden and Kamala Harris will raise your taxes ',
#        'description': "Biden's far-left agenda will cost the average American family $6,500 per year.",
#        'embeddable': True,
#        'monetizable': False},
#       'media_url': 'http://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#       'url': 'https://t.co/BT9sTqsDfK',
#       'display_url': 'pic.twitter.com/BT9sTqsDfK',
#       'expanded_url': 'https://twitter.com/TrumpWarRoom/status/1322313887107239936/video/1',
#       'type': 'video',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 8900,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/1280x720/FBo9NGnsAzFvXV3g.mp4?tag=13'},
#         {'bitrate': 288000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/480x270/oIp6HGnYJggXBRY6.mp4?tag=13'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/1322312618372177926/pl/JyfNhvzAQZT7-6xt.m3u8?tag=13'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/640x360/r30Eym-ZxZVDQoou.mp4?tag=13'}]},
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#        'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 360, 'resize': 'fit'}}}]},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/3jPh6E7tZo',
#    'expanded': 'https://twitter.com/trumpwarroom/status/1322313887107239936',
#    'display': 'twitter.com/trumpwarroom/s…'},
#   'is_quote_status': True,
#   'quote_count': 856,
#   'reply_count': 2117,
#   'retweet_count': 7722,
#   'favorite_count': 20093,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_id': 1322313887107239936,
#  'quoted_status_id_str': '1322313887107239936',
#  'quoted_status': {'created_at': 'Fri Oct 30 23:06:12 +0000 2020',
#   'id': 1322313887107239936,
#   'id_str': '1322313887107239936',
#   'text': '"Joe Biden and I are about to work to get rid of that tax cut," Kamala Harris tells Hispanic Americans. https://t.co/BT9sTqsDfK',
#   'display_text_range': [0, 103],
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1108472017144201216,
#    'id_str': '1108472017144201216',
#    'name': 'Trump War Room - Text TRUMP to 88022',
#    'screen_name': 'TrumpWarRoom',
#    'location': 'MAGA Country',
#    'url': 'https://www.donaldjtrump.com/',
#    'description': "Highlighting @realDonaldTrump's #PromisesKept, fighting #FakeNews. This account punches back 10x harder. Managed by the #TeamTrump 2020 campaign. #MAGA",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 976809,
#    'friends_count': 278,
#    'listed_count': 2887,
#    'favourites_count': 99,
#    'statuses_count': 25881,
#    'created_at': 'Wed Mar 20 20:54:58 +0000 2019',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1109170568950095879/Q5nCWHLB_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109170568950095879/Q5nCWHLB_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1108472017144201216/1588976113',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 2434,
#   'reply_count': 2448,
#   'retweet_count': 7497,
#   'favorite_count': 12367,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': [],
#    'media': [{'id': 1322312618372177926,
#      'id_str': '1322312618372177926',
#      'indices': [104, 127],
#      'additional_media_info': {'title': 'Joe Biden and Kamala Harris will raise your taxes ',
#       'description': "Biden's far-left agenda will cost the average American family $6,500 per year.",
#       'embeddable': True,
#       'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#      'url': 'https://t.co/BT9sTqsDfK',
#      'display_url': 'pic.twitter.com/BT9sTqsDfK',
#      'expanded_url': 'https://twitter.com/TrumpWarRoom/status/1322313887107239936/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#       'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 360, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1322312618372177926,
#      'id_str': '1322312618372177926',
#      'indices': [104, 127],
#      'additional_media_info': {'title': 'Joe Biden and Kamala Harris will raise your taxes ',
#       'description': "Biden's far-left agenda will cost the average American family $6,500 per year.",
#       'embeddable': True,
#       'monetizable': False},
#      'media_url': 'http://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/ElnMfQXWkAISO8H.jpg',
#      'url': 'https://t.co/BT9sTqsDfK',
#      'display_url': 'pic.twitter.com/BT9sTqsDfK',
#      'expanded_url': 'https://twitter.com/TrumpWarRoom/status/1322313887107239936/video/1',
#      'type': 'video',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 8900,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/1280x720/FBo9NGnsAzFvXV3g.mp4?tag=13'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/480x270/oIp6HGnYJggXBRY6.mp4?tag=13'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1322312618372177926/pl/JyfNhvzAQZT7-6xt.m3u8?tag=13'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1322312618372177926/vid/640x360/r30Eym-ZxZVDQoou.mp4?tag=13'}]},
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 640, 'h': 360, 'resize': 'fit'},
#       'medium': {'w': 640, 'h': 360, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 360, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/3jPh6E7tZo',
#   'expanded': 'https://twitter.com/trumpwarroom/status/1322313887107239936',
#   'display': 'twitter.com/trumpwarroom/s…'},
#  'is_quote_status': True,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'EricTrump',
#     'name': 'Eric Trump',
#     'id': 39349894,
#     'id_str': '39349894',
#     'indices': [3, 13]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1604163831843'}

# %%
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
            "user": "@%s" % item["user"]["screen_name"],
            "source": item["source"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
#                        created_at  \
# 0  Sat Oct 31 17:03:51 +0000 2020
# 1  Sat Oct 31 17:03:51 +0000 2020
# 2  Sat Oct 31 17:03:51 +0000 2020
# 3  Sat Oct 31 17:03:51 +0000 2020
# 4  Sat Oct 31 17:03:51 +0000 2020
#
#                                                 text             user  \
# 0  RT @EricTrump: Once again, Joe and Kamala prom...    @elliotbsmith
# 1  RT @mmpadellan: Kamala Harris is speaking in M...  @LASWestCoaster
# 2  RT @th3j35t3r: "LAW AND ORDER!" - What a fucki...  @mersenne859433
# 3  RT @DogginTrump: Make sure you all share this ...   @twindad031207
# 4  RT @Annakhait: Biden/Harris campaign bus escor...    @kinh_nguyen9
#
#                                               source lang
# 0  <a href="http://twitter.com/download/android" ...   en
# 1  <a href="http://twitter.com/download/android" ...   en
# 2  <a href="https://mobile.twitter.com" rel="nofo...   en
# 3  <a href="http://twitter.com/download/android" ...   en
# 4  <a href="http://twitter.com/download/iphone" r...   en

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(dataset.text)

word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0            rt   3599
# 1           the   2835
# 2            to   2682
# 3        harris   2521
# 4         biden   2329
# 5           and   1432
# 6         https   1400
# 7            is   1307
# 8            co   1283
# 9          this   1248
# 10           of   1128
# 11        trump   1085
# 12        texas    982
# 13          bus    956
# 14           in    915
# 15          for    868
# 16       kamala    800
# 17           on    730
# 18         with    649
# 19   supporters    528
# 20         vote    514
# 21          out    492
# 22           at    476
# 23          you    459
# 24           up    448
# 25     campaign    443
# 26          are    443
# 27  ericcervini    432
# 28           we    412
# 29         down    398
# 30           by    396
# 31         tour    388
# 32         help    384
# 33      instead    372
# 34      polling    369
# 35         flew    362
# 36     intended    359
# 37   enthusiasm    359
# 38           it    358
# 39    locations    357
# 40         drum    357
# 41         they    350
# 42         that    313
# 43          joe    285
# 44           if    282
# 45        taxes    277
# 46         here    272
# 47         have    263
# 48          was    261
# 49        their    249

# %%
def get_source_name(x):
    value = re.findall(pattern="<[^>]+>([^<]+)</a>", string=x)
    if len(value) > 0:
        return value[0]
    else:
        return ""
dataset.source_name = dataset.source.apply(get_source_name)

source_counts = dataset.source_name.value_counts().sort_values()[-10:]

bottom = [index for index, item in enumerate(source_counts.index)]
plt.barh(bottom, width=source_counts, color="blue", linewidth=0)

y_labels = ["%s %.1f%%" % (item, 100.0*source_counts[item]/len(dataset)) for index,item in enumerate(source_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)

source_counts
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   import sys
# Twitterrific for iOS          3
# WordPress.com                 3
# TweetCaster for Android       8
# dlvr.it                       8
# Tweetbot for iΟS             10
# TweetDeck                    26
# Twitter for iPad            278
# Twitter Web App            1139
# Twitter for Android        1345
# Twitter for iPhone         2139
# Name: source, dtype: int64

# %%
lang_counts = dataset.lang.value_counts().sort_values()[-10:]
bottom = [index for index, item in enumerate(lang_counts.index)]
plt.barh(bottom, width=lang_counts, color="green", linewidth=0)
y_labels = ["%s %.1f%%" % (item, 100.0*lang_counts[item]/len(dataset)) for index,item in enumerate(lang_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)
lang_counts
# Out:
# ja        7
# in        7
# nl        8
# fr       11
# tl       11
# pt       20
# es       37
# ca       44
# und     176
# en     4650
# Name: lang, dtype: int64

# %%
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt

# %%
dataset1 = [{"id": item["id"],
            "text": item["text"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset1 = pd.DataFrame(dataset1)
is_dataset1=dataset1.lang=="en"
dataset1=dataset1[is_dataset1]
dataset1
# Out:
#                        id                                               text  \
# 0     1322585087012229120  RT @EricTrump: Once again, Joe and Kamala prom...
# 1     1322585087376977921  RT @mmpadellan: Kamala Harris is speaking in M...
# 2     1322585087385325569  RT @th3j35t3r: "LAW AND ORDER!" - What a fucki...
# 3     1322585087515463683  RT @DogginTrump: Make sure you all share this ...
# 4     1322585087611985921  RT @Annakhait: Biden/Harris campaign bus escor...
# ...                   ...                                                ...
# 4994  1322587748902096896              RT @SykesCharlie: This is really bad.
# 4995  1322587748944011271  RT @ericcervini: I flew down to Texas to help ...
# 4996  1322587749346664448  RT @Q17Follow: If you don’t want to be in a co...
# 4997  1322587750248390662  RT @ChutzpahZA: Biden Rapping to Bob Marley Vi...
# 4998  1322587750604955650  RT @GovMikeHuckabee: Yes, It's Time to Talk Ab...
#
#      lang
# 0      en
# 1      en
# 2      en
# 3      en
# 4      en
# ...   ...
# 4994   en
# 4995   en
# 4996   en
# 4997   en
# 4998   en
#
# [4650 rows x 3 columns]

# %%
from  textblob import TextBlob
tweettext=dataset1['text']
wordlist=pd.DataFrame();

polarity=[]
subj=[]

for t in tweettext:
    tx= TextBlob(t)
    polarity.append(tx.sentiment.polarity)
    subj.append(tx.sentiment.subjectivity)

poltweet= pd.DataFrame({'polarity':polarity,'subjectivity':subj})
poltweet.polarity.plot(title='Polarity')
plt.show()

# %%
poltweet.subjectivity.plot(title='Subjectivity')
plt.show()

# %%
import statistics
statistics.mean(poltweet.polarity)
# Out:
# 0.031991389678659714

# %%
import statistics
statistics.mean(poltweet.subjectivity)
# Out:
# 0.2948774555094448

# %%
#Fuction to get clean text to get better analysis
def cleanText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

dataset1['text'] = dataset1['text'].apply(cleanText)

dataset1
# Out:
#                        id                                               text  \
# 0     1322585087012229120  : Once again, Joe and Kamala promise to raise ...
# 1     1322585087376977921  : Kamala Harris is speaking in Miami now.\n\nB...
# 2     1322585087385325569         : "LAW AND ORDER!" - What a fucking joke.
# 3     1322585087515463683  : Make sure you all share this everywhere. The...
# 4     1322585087611985921  : Biden/Harris campaign bus escorted out of Te...
# ...                   ...                                                ...
# 4994  1322587748902096896                              : This is really bad.
# 4995  1322587748944011271  : I flew down to Texas to help with the Biden/...
# 4996  1322587749346664448  : If you don’t want to be in a communist conce...
# 4997  1322587750248390662  : Biden Rapping to Bob Marley Vibe, with Harri...
# 4998  1322587750604955650  : Yes, It's Time to Talk About President Kamal...
#
#      lang
# 0      en
# 1      en
# 2      en
# 3      en
# 4      en
# ...   ...
# 4994   en
# 4995   en
# 4996   en
# 4997   en
# 4998   en
#
# [4650 rows x 3 columns]

# %%
#Fuction to get subjectivity and polarity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

dataset1['Subjectivity'] = dataset1['text'].apply(getSubjectivity)
dataset1['Polarity'] = dataset1['text'].apply(getPolarity)

dataset1.head()
# Out:
#                     id                                               text  \
# 0  1322585087012229120  : Once again, Joe and Kamala promise to raise ...
# 1  1322585087376977921  : Kamala Harris is speaking in Miami now.\n\nB...
# 2  1322585087385325569         : "LAW AND ORDER!" - What a fucking joke.
# 3  1322585087515463683  : Make sure you all share this everywhere. The...
# 4  1322585087611985921  : Biden/Harris campaign bus escorted out of Te...
#
#   lang  Subjectivity  Polarity
# 0   en      0.000000      0.00
# 1   en      0.700000      0.10
# 2   en      0.800000     -0.60
# 3   en      0.794444      0.05
# 4   en      0.000000      0.00

# %%
#Function to compute positive negative neutral analysis
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
dataset1['Analysis'] = dataset1['Polarity'].apply(getAnalysis)

dataset1.head()
# Out:
#                     id                                               text  \
# 0  1322585087012229120  : Once again, Joe and Kamala promise to raise ...
# 1  1322585087376977921  : Kamala Harris is speaking in Miami now.\n\nB...
# 2  1322585087385325569         : "LAW AND ORDER!" - What a fucking joke.
# 3  1322585087515463683  : Make sure you all share this everywhere. The...
# 4  1322585087611985921  : Biden/Harris campaign bus escorted out of Te...
#
#   lang  Subjectivity  Polarity  Analysis
# 0   en      0.000000      0.00   Neutral
# 1   en      0.700000      0.10  Positive
# 2   en      0.800000     -0.60  Negative
# 3   en      0.794444      0.05  Positive
# 4   en      0.000000      0.00   Neutral

# %%
#percentage of positive
ptweets = dataset1[dataset1.Analysis == 'Positive']
ptweets = ptweets['text']

round( (ptweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 30.9

# %%
#percentage of negative
ntweets = dataset1[dataset1.Analysis == 'Negative']
ntweets = ntweets['text']

round( (ntweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 21.4

# %%
#percentage of neutral
neutweets = dataset1[dataset1.Analysis == 'Neutral']
neutweets = neutweets['text']

round( (neutweets.shape[0] / dataset1.shape[0]) *100,1)
# Out:
# 47.7

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

def wc(data,bgcolor,title):
    plt.figure(figsize = (10,10))
    wc = WordCloud(background_color = bgcolor, max_words = 100,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
top_N = 100
#convert list of list into text
#a=''.join(str(r) for v in df_usa['title'] for r in v)

a = dataset1['text'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
b = re.sub('[^A-Za-z]+', ' ', a)
nltk.download('stopwords')
#remove all the stopwords from the text
nltk.download('punkt')
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import seaborn as sns
# Remove characters which have length less than 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        

# Calculate frequency distribution
word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure()
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Common Words' )

# %%
from textblob import TextBlob

bloblist_desc = list()

twit=dataset1['text'].astype(str)
for row in twit:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    twit_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
    
def f(twit_polarity_desc):
    if twit_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif twit_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

twit_polarity_desc['Sentiment_Type'] = twit_polarity_desc.apply(f, axis=1)

plt.figure()
sns.set_style("whitegrid")
ax = sns.countplot(x="Sentiment_Type", data=twit_polarity_desc)

# %%
import collections, numpy as np
a=twit_polarity_desc.Sentiment_Type
neut=np.count_nonzero(a == 'Neutral')
pos=np.count_nonzero(a == 'Positive')
neg=np.count_nonzero(a == 'Negative')
popularity='{0:.2f}'.format((((neut*0.5)+(pos)+(neg*0))/(neut+pos+neg))*100)
popularity
# Out:
# '54.77'
